# %% [markdown]
# <a href="https://colab.research.google.com/github/Cjbeej/cs1-python-Diamond-Pausang-better/blob/main/cs1_python_Diamond_Pausang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# maxnum - Program to find the biggest number among three numbers

# Ask the user to input three numbers
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

# Compare the numbers to find the biggest
if num1 >= num2 and num1 >= num3:
    biggest = num1
elif num2 >= num1 and num2 >= num3:
    biggest = num2
else:
    biggest = num3

# Print the biggest number
print("The biggest number is:", biggest)
# Out:
# Enter the first number: 32
# Enter the second number: 33
# Enter the third number: 34
# The biggest number is: 34.0
